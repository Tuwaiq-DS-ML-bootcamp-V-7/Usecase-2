# %%
#Import all relevant libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import zscore
 
## This statement allows the visuals to render within your Jupyter Notebook.
# %matplotlib inline

# %% [markdown]
# ## Loading the data
# We can now load the dataset into pandas using the read_csv() function. This converts the CSV file into a Pandas dataframe.

# %%
df_2015 = pd.read_csv("C:/Users/foooo/Downloads/archive (6)/2015.csv")
df_2016 = pd.read_csv("C:/Users/foooo/Downloads/archive (6)/2016.csv")
df_2017 = pd.read_csv("C:/Users/foooo/Downloads/archive (6)/2017.csv")

# %% [markdown]
# ### Viewing the dataframe
# We can get a quick sense of the size of our dataset by using the shape method. This returns a tuple with the number of rows and columns in the dataset.

# %%
df_2015.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
df_2016.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
# 3       Norway  Western Europe               4            7.498
# 4      Finland  Western Europe               5            7.413
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      7.460                      7.592
# 1                      7.428                      7.590
# 2                      7.333                      7.669
# 3                      7.421                      7.575
# 4                      7.351                      7.475
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.44178  1.16374                   0.79504  0.57941
# 1                   1.52733  1.14524                   0.86303  0.58557
# ...

# %%
df_2017.head()
# Out:
#        Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0       Norway               1            7.537      7.594445     7.479556
# 1      Denmark               2            7.522      7.581728     7.462272
# 2      Iceland               3            7.504      7.622030     7.385970
# 3  Switzerland               4            7.494      7.561772     7.426227
# 4      Finland               5            7.469      7.527542     7.410458
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 0                  1.616463  1.533524                  0.796667  0.635423
# 1                  1.482383  1.551122                  0.792566  0.626007
# 2                  1.480633  1.610574                  0.833552  0.627163
# 3                  1.564980  1.516912                  0.858131  0.620071
# 4                  1.443572  1.540247                  0.809158  0.617951
#
#    Generosity  Trust..Government.Corruption.  Dystopia.Residual
# ...

# %% [markdown]
# ## 1. Data Profiling:
# Data profiling is a comprehensive process of examining the data available in an existing dataset and collecting statistics and information about that data.

# %%
df_2015.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
#I do not have any missing values at any column
#data type :
#2 string
#1 int 
#9 float

# %%
df_2015.shape
# Out:
# (158, 12)

# %%
# I have 158 rows

# %%
df_2015.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %%
df_2015.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
df_2016.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 13 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        157 non-null    object
#  1   Region                         157 non-null    object
#  2   Happiness Rank                 157 non-null    int64
#  3   Happiness Score                157 non-null    float64
#  4   Lower Confidence Interval      157 non-null    float64
#  5   Upper Confidence Interval      157 non-null    float64
#  6   Economy (GDP per Capita)       157 non-null    float64
#  7   Family                         157 non-null    float64
#  8   Health (Life Expectancy)       157 non-null    float64
#  9   Freedom                        157 non-null    float64
#  10  Trust (Government Corruption)  157 non-null    float64
#  11  Generosity                     157 non-null    float64
# ...

# %%
#I do not have any missing values at any column
#data type :
#2 string
#1 int 
#10 float

# %%
df_2016.shape
# Out:
# (157, 13)

# %%
# Ihave 157 rows

# %%
df_2016.describe()
# Out:
#        Happiness Rank  Happiness Score  Lower Confidence Interval  \
# count      157.000000       157.000000                 157.000000
# mean        78.980892         5.382185                   5.282395
# std         45.466030         1.141674                   1.148043
# min          1.000000         2.905000                   2.732000
# 25%         40.000000         4.404000                   4.327000
# 50%         79.000000         5.314000                   5.237000
# 75%        118.000000         6.269000                   6.154000
# max        157.000000         7.526000                   7.460000
#
#        Upper Confidence Interval  Economy (GDP per Capita)      Family  \
# count                 157.000000                157.000000  157.000000
# mean                    5.481975                  0.953880    0.793621
# std                     1.136493                  0.412595    0.266706
# min                     3.078000                  0.000000    0.000000
# ...

# %%
df_2016.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Lower Confidence Interval', 'Upper Confidence Interval',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Trust (Government Corruption)', 'Generosity',
#        'Dystopia Residual'],
#       dtype='object')

# %%
df_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 155 entries, 0 to 154
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        155 non-null    object
#  1   Happiness.Rank                 155 non-null    int64
#  2   Happiness.Score                155 non-null    float64
#  3   Whisker.high                   155 non-null    float64
#  4   Whisker.low                    155 non-null    float64
#  5   Economy..GDP.per.Capita.       155 non-null    float64
#  6   Family                         155 non-null    float64
#  7   Health..Life.Expectancy.       155 non-null    float64
#  8   Freedom                        155 non-null    float64
#  9   Generosity                     155 non-null    float64
#  10  Trust..Government.Corruption.  155 non-null    float64
#  11  Dystopia.Residual              155 non-null    float64
# ...

# %%
#I do not have any missing values at any column
#data type :
#1 string
#1 int 
#10 float

# %%
df_2017.shape
# Out:
# (155, 12)

# %%
#I have 155 rows

# %%
df_2017.describe()
# Out:
#        Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# count      155.000000       155.000000    155.000000   155.000000
# mean        78.000000         5.354019      5.452326     5.255713
# std         44.888751         1.131230      1.118542     1.145030
# min          1.000000         2.693000      2.864884     2.521116
# 25%         39.500000         4.505500      4.608172     4.374955
# 50%         78.000000         5.279000      5.370032     5.193152
# 75%        116.500000         6.101500      6.194600     6.006527
# max        155.000000         7.537000      7.622030     7.479556
#
#        Economy..GDP.per.Capita.      Family  Health..Life.Expectancy.  \
# count                155.000000  155.000000                155.000000
# mean                   0.984718    1.188898                  0.551341
# std                    0.420793    0.287263                  0.237073
# min                    0.000000    0.000000                  0.000000
# ...

# %%
df_2017.columns
# Out:
# Index(['Country', 'Happiness.Rank', 'Happiness.Score', 'Whisker.high',
#        'Whisker.low', 'Economy..GDP.per.Capita.', 'Family',
#        'Health..Life.Expectancy.', 'Freedom', 'Generosity',
#        'Trust..Government.Corruption.', 'Dystopia.Residual'],
#       dtype='object')

# %%
df_2015.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
#Country =  Qualitative , nominal
#Region = Qualitative , nominal
#Happiness Rank	= Quantitative , discrete
#Happiness Score = Quantitative, cont
#Standard Error = Quantitative, cont
#Economy (GDP per Capita) = Quantitative, cont
#Family = Quantitative, cont
#Health = Quantitative, cont
#Freedom	= Quantitative, cont
#Trust (Government Corruption) = Quantitative, cont
#Generosity = Quantitative, cont
#Dystopia Residual  = Quantitative, cont

# %%
df_2016.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
# 3       Norway  Western Europe               4            7.498
# 4      Finland  Western Europe               5            7.413
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      7.460                      7.592
# 1                      7.428                      7.590
# 2                      7.333                      7.669
# 3                      7.421                      7.575
# 4                      7.351                      7.475
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.44178  1.16374                   0.79504  0.57941
# 1                   1.52733  1.14524                   0.86303  0.58557
# ...

# %%
#Country =  Qualitative , nominal
#Region = Qualitative , nominal
#Happiness Rank	= Quantitative , discrete
#Happiness Score = Quantitative, cont
#Lower Confidence Interval = Quantitative, cont
#Upper Confidence Interval = Quantitative, cont
#Economy (GDP per Capita) = Quantitative, cont
#Family = Quantitative, cont
#Health = Quantitative, cont
#Freedom	= Quantitative, cont
#Trust (Government Corruption) = Quantitative, cont
#Generosity = Quantitative, cont
#Dystopia Residual  = Quantitative, cont

# %%
df_2017.head()
# Out:
#        Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0       Norway               1            7.537      7.594445     7.479556
# 1      Denmark               2            7.522      7.581728     7.462272
# 2      Iceland               3            7.504      7.622030     7.385970
# 3  Switzerland               4            7.494      7.561772     7.426227
# 4      Finland               5            7.469      7.527542     7.410458
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 0                  1.616463  1.533524                  0.796667  0.635423
# 1                  1.482383  1.551122                  0.792566  0.626007
# 2                  1.480633  1.610574                  0.833552  0.627163
# 3                  1.564980  1.516912                  0.858131  0.620071
# 4                  1.443572  1.540247                  0.809158  0.617951
#
#    Generosity  Trust..Government.Corruption.  Dystopia.Residual
# ...

# %%
#Country                 = Qualitative , nominal
#Happiness.Rank          =  Quantitative , discrete
#Happiness.Score         =  Quantitative, cont
#Whisker.high            = Quantitative, cont
#Whisker.low             = Quantitative, cont
#Economy..GDP.per.Capita = Quantitative, cont
#Family                  = Quantitative, cont
#Health..Life.Expectancy.= Quantitative, cont
#Freedom                 = Quantitative, cont
#Generosity              = Quantitative, cont
#Trust..Government.Corruption  = Quantitative, cont
#Dystopia.Residua              = Quantitative, cont

# %% [markdown]
# The process of profiling differs slightly for categorical and numerical variables due to their inherent differences.
#
# **The two main types of data are:**
# - Quantitative (numerical) data
# - Qualitative (categorical) data

# %% [markdown]
# ### Data Quality Checks
# Data quality checks involve the process of ensuring that the data is accurate, complete, consistent, relevant, and reliable.
#
#
# **Here are typical steps involved in checking data quality:**

# %% [markdown]
# #### 1. Reliability:
# Evaluate the data's source and collection process to determine its trustworthiness.

# %%
# The data from the Gallup World Poll.

# %% [markdown]
# #### 2. Timeliness:
# Ensure the data is up-to-date and reflective of the current situation or the period of interest for the analysis.

# %%
#There version 2019 but our scope need 2015,2016 and 2017

# %% [markdown]
# #### 3. Consistency:
#
# Confirm that the data is consistent within the dataset and across multiple data sources. For example, the same data point should not have different values in different places.

# %%
df_2015['Year'] = 2015
df_2015.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
df_2016 ['Year'] = 2016
df_2016.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
# 3       Norway  Western Europe               4            7.498
# 4      Finland  Western Europe               5            7.413
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      7.460                      7.592
# 1                      7.428                      7.590
# 2                      7.333                      7.669
# 3                      7.421                      7.575
# 4                      7.351                      7.475
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.44178  1.16374                   0.79504  0.57941
# 1                   1.52733  1.14524                   0.86303  0.58557
# ...

# %%
df_2017 ['Year'] = 2017
df_2017.head()
# Out:
#        Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0       Norway               1            7.537      7.594445     7.479556
# 1      Denmark               2            7.522      7.581728     7.462272
# 2      Iceland               3            7.504      7.622030     7.385970
# 3  Switzerland               4            7.494      7.561772     7.426227
# 4      Finland               5            7.469      7.527542     7.410458
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 0                  1.616463  1.533524                  0.796667  0.635423
# 1                  1.482383  1.551122                  0.792566  0.626007
# 2                  1.480633  1.610574                  0.833552  0.627163
# 3                  1.564980  1.516912                  0.858131  0.620071
# 4                  1.443572  1.540247                  0.809158  0.617951
#
#    Generosity  Trust..Government.Corruption.  Dystopia.Residual  Year
# ...

# %%
#change the names of deffrent columns in data files
df_2017.rename(columns={'Happiness.Rank': 'Happiness Rank', 'Happiness.Score': 'Happiness Score',
                        'Economy..GDP.per.Capita.' : 'Economy (GDP per Capita)',
                        'Dystopia.Residual' : 'Dystopia Residual',
                        'Health..Life.Expectancy.' : 'Health (Life Expectancy)',
                        'Trust..Government.Corruption.': 'Trust (Government Corruption)',
                       }, inplace= True )

# %%
print(df_2015.columns)
print(df_2016.columns)
print(df_2017.columns)
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual', 'Year'],
#       dtype='object')
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Lower Confidence Interval', 'Upper Confidence Interval',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Trust (Government Corruption)', 'Generosity',
#        'Dystopia Residual', 'Year'],
#       dtype='object')
# Index(['Country', 'Happiness Rank', 'Happiness Score', 'Whisker.high',
#        'Whisker.low', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Generosity',
#        'Trust (Government Corruption)', 'Dystopia Residual', 'Year'],
#       dtype='object')

# %%
df_2015.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
df_2016.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
# 3       Norway  Western Europe               4            7.498
# 4      Finland  Western Europe               5            7.413
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      7.460                      7.592
# 1                      7.428                      7.590
# 2                      7.333                      7.669
# 3                      7.421                      7.575
# 4                      7.351                      7.475
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.44178  1.16374                   0.79504  0.57941
# 1                   1.52733  1.14524                   0.86303  0.58557
# ...

# %%
df_2017.head()
# Out:
#        Country  Happiness Rank  Happiness Score  Whisker.high  Whisker.low  \
# 0       Norway               1            7.537      7.594445     7.479556
# 1      Denmark               2            7.522      7.581728     7.462272
# 2      Iceland               3            7.504      7.622030     7.385970
# 3  Switzerland               4            7.494      7.561772     7.426227
# 4      Finland               5            7.469      7.527542     7.410458
#
#    Economy (GDP per Capita)    Family  Health (Life Expectancy)   Freedom  \
# 0                  1.616463  1.533524                  0.796667  0.635423
# 1                  1.482383  1.551122                  0.792566  0.626007
# 2                  1.480633  1.610574                  0.833552  0.627163
# 3                  1.564980  1.516912                  0.858131  0.620071
# 4                  1.443572  1.540247                  0.809158  0.617951
#
#    Generosity  Trust (Government Corruption)  Dystopia Residual  Year
# ...

# %%
df_2017.head()
# Out:
#        Country  Happiness Rank  Happiness Score  Whisker.high  Whisker.low  \
# 0       Norway               1            7.537      7.594445     7.479556
# 1      Denmark               2            7.522      7.581728     7.462272
# 2      Iceland               3            7.504      7.622030     7.385970
# 3  Switzerland               4            7.494      7.561772     7.426227
# 4      Finland               5            7.469      7.527542     7.410458
#
#    Economy (GDP per Capita)    Family  Health (Life Expectancy)   Freedom  \
# 0                  1.616463  1.533524                  0.796667  0.635423
# 1                  1.482383  1.551122                  0.792566  0.626007
# 2                  1.480633  1.610574                  0.833552  0.627163
# 3                  1.564980  1.516912                  0.858131  0.620071
# 4                  1.443572  1.540247                  0.809158  0.617951
#
#    Generosity  Trust (Government Corruption)  Dystopia Residual  Year
# ...

# %%
print(df_2015.shape)
print(df_2016.shape)
print(df_2017.shape)
# Out:
# (158, 13)
# (157, 14)
# (155, 13)

# %%
try1_df = pd.concat([df_2015,df_2016,df_2017])

# %%
try1_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 470 entries, 0 to 154
# Data columns (total 17 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        470 non-null    object
#  1   Region                         315 non-null    object
#  2   Happiness Rank                 470 non-null    int64
#  3   Happiness Score                470 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       470 non-null    float64
#  6   Family                         470 non-null    float64
#  7   Health (Life Expectancy)       470 non-null    float64
#  8   Freedom                        470 non-null    float64
#  9   Trust (Government Corruption)  470 non-null    float64
#  10  Generosity                     470 non-null    float64
#  11  Dystopia Residual              470 non-null    float64
# ...

# %% [markdown]
# #### 4. Relevance:
# Assess whether the data is appropriate and applicable for the intended analysis. Data that is not relevant can skew results and lead to incorrect conclusions.
#
# **Key considerations for relevance include:**
#
# > 1. Sample Appropriateness: Confirm that your data sample aligns with your analysis objectives. For instance, utilizing data from the Northern region will not yield accurate insights for the Western region of the Kingdom.
# >
# > 2. Variable Selection: Any column will not be relevant for our analysis, we can get rid of these using the drop() method. We will set the “axis” argument to 1 since we’re dealing with columns, and set the “inplace” argument to True to make the change permanent.

# %%
try1_df.drop(['Standard Error','Lower Confidence Interval','Upper Confidence Interval','Whisker.high','Whisker.low'],axis=1,inplace=True)

# %%
try1_df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.39651  1.34951                   0.94143  0.66557
# 1                   1.30232  1.40223                   0.94784  0.62877
# 2                   1.32548  1.36058                   0.87464  0.64938
# 3                   1.45900  1.33095                   0.88521  0.66973
# 4                   1.32629  1.32261                   0.90563  0.63297
#
#    Trust (Government Corruption)  Generosity  Dystopia Residual  Year
# 0                        0.41978     0.29678            2.51738  2015
# ...

# %% [markdown]
# #### 5. Uniqueness:
# Check for and remove duplicate records to prevent skewed analysis results.

# %%
try1_df.duplicated().sum()
# Out:
# 0

# %%
# go to delete duplicates columns

# %% [markdown]
# #### 6. Completeness:
# Ensure that no critical data is missing. This might mean checking for null values or required fields that are empty.
#
# We will start by checking the dataset for missing or null values. For this, we can use the isna() method which returns a dataframe of boolean values indicating if a field is null or not. To group all missing values by column, we can include the sum() method.

# %%
try1_df.isnull().sum().sort_values(ascending = False)
# Out:
# Region                           155
# Country                            0
# Happiness Rank                     0
# Happiness Score                    0
# Economy (GDP per Capita)           0
# Family                             0
# Health (Life Expectancy)           0
# Freedom                            0
# Trust (Government Corruption)      0
# Generosity                         0
# Dystopia Residual                  0
# Year                               0
# dtype: int64

# %%
#to get the country realated to Region
region_dict = df_2015 [["Country","Region"]].to_dict("index")
region_dict = df_2016 [["Country","Region"]].to_dict("index")

# %%
# to save name country as key
dic_1 = {}
for x, y in region_dict.items():
    dic_1[list(y.values())[0]] = list(y.values())[1]
    #print(list(y.values())[0])
#print(list_fill)

# %%
try1_df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.39651  1.34951                   0.94143  0.66557
# 1                   1.30232  1.40223                   0.94784  0.62877
# 2                   1.32548  1.36058                   0.87464  0.64938
# 3                   1.45900  1.33095                   0.88521  0.66973
# 4                   1.32629  1.32261                   0.90563  0.63297
#
#    Trust (Government Corruption)  Generosity  Dystopia Residual  Year
# 0                        0.41978     0.29678            2.51738  2015
# ...

# %%
# to fill
CIDF = 0  # counter 
for i in try1_df['Country']:
    if try1_df.iloc[CIDF, 0] == i:
        if i in dic_1:
            try1_df.iloc[CIDF, 1] = dic_1[i]
        else:
            print(f"'{i}' not found in dic_1") 
    CIDF += 1
# Out:
# 'Oman' not found in dic_1
# 'Somaliland region' not found in dic_1
# 'Mozambique' not found in dic_1
# 'Lesotho' not found in dic_1
# 'Swaziland' not found in dic_1
# 'Djibouti' not found in dic_1
# 'Central African Republic' not found in dic_1
# 'Taiwan Province of China' not found in dic_1
# 'Hong Kong S.A.R., China' not found in dic_1
# 'Mozambique' not found in dic_1
# 'Lesotho' not found in dic_1
# 'Central African Republic' not found in dic_1

# %%
try1_df.isnull().sum().sort_values(ascending = False)
# Out:
# Region                           5
# Country                          0
# Happiness Rank                   0
# Happiness Score                  0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# Year                             0
# dtype: int64

# %%
try1_df["Region"].fillna("unknown", inplace = True)

# %%
res = try1_df.loc[try1_df['Region'] == 'unknown'] 
res
# Out:
#                       Country   Region  Happiness Rank  Happiness Score  \
# 32   Taiwan Province of China  unknown              33            6.422
# 70    Hong Kong S.A.R., China  unknown              71            5.472
# 112                Mozambique  unknown             113            4.550
# 138                   Lesotho  unknown             139            3.808
# 154  Central African Republic  unknown             155            2.693
#
#      Economy (GDP per Capita)    Family  Health (Life Expectancy)   Freedom  \
# 32                   1.433627  1.384565                  0.793984  0.361467
# 70                   1.551675  1.262791                  0.943062  0.490969
# 112                  0.234306  0.870701                  0.106654  0.480791
# 138                  0.521021  1.190095                  0.000000  0.390661
# 154                  0.000000  0.000000                  0.018773  0.270842
#
#      Trust (Government Corruption)  Generosity  Dystopia Residual  Year
# ...

# %%
#try1_df['Region']= #try1_df[].replace('-', 0)
#try3_df = try1_df.copy()
#try1_df[(try1_df['Region'] == 'unknown') & (try1_df['Country'] == 'Taiwan Province of China')] = try1_df[(try1_df['Region'] == 'unknown') & (try1_df['Country'] == 'Taiwan Province of China')].replace('unknown','Eastern Asia')
#try1_df[(try1_df['Region'] == 'unknown') & (try1_df['Country'] == 'Hong Kong S.A.R., China')] = try1_df[(try1_df['Region'] == 'unknown') & (try1_df['Country'] == 'Hong Kong S.A.R., China')].replace('unknown','Eastern Asia')
#try1_df[(try1_df['Region'] == 'unknown') & (try1_df['Country'] == 'Mozambique')] = try1_df[(try1_df['Region'] == 'unknown') & (try1_df['Country'] == 'Taiwan Province of China')].replace('unknown','Sub-Saharan Africa')
#try1_df[(try1_df['Region'] == 'unknown') & (try1_df['Country'] == 'Lesotho')] = try1_df[(try1_df['Region'] == 'unknown') & (try1_df['Country'] == 'Lesotho')].replace('unknown','Sub-Saharan Africa')
#try1_df[(try1_df['Region'] == 'unknown') & (try1_df['Country'] == 'Central African Republic')] = try1_df[(try1_df['Region'] == 'unknown') & (try1_df['Country'] == 'Central African Republic')].replace('unknown','Sub-Saharan Africa')

#try3_df[(try3_df['Region'] == 'unknown') & (try3_df['Country'] )]

# %%
try1_df.loc[(try1_df['Region'] == 'unknown') & (try1_df['Country'] == 'Taiwan Province of China'), 'Region'] = 'Eastern Asia'
try1_df.loc[(try1_df['Region'] == 'unknown') & (try1_df['Country'] == 'Hong Kong S.A.R., China'), 'Region'] = 'Eastern Asia'
try1_df.loc[(try1_df['Region'] == 'unknown') & (try1_df['Country'] == 'Mozambique'), 'Region'] = 'Sub-Saharan Africa'
try1_df.loc[(try1_df['Region'] == 'unknown') & (try1_df['Country'] == 'Lesotho'), 'Region'] = 'Sub-Saharan Africa'
try1_df.loc[(try1_df['Region'] == 'unknown') & (try1_df['Country'] == 'Central African Republic'), 'Region'] = 'Sub-Saharan Africa'

# %%
try1_df[(try1_df['Region'] == 'unknown')]
# Out:
# Empty DataFrame
# Columns: [Country, Region, Happiness Rank, Happiness Score, Economy (GDP per Capita), Family, Health (Life Expectancy), Freedom, Trust (Government Corruption), Generosity, Dystopia Residual, Year]
# Index: []

# %%
try1_df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.39651  1.34951                   0.94143  0.66557
# 1                   1.30232  1.40223                   0.94784  0.62877
# 2                   1.32548  1.36058                   0.87464  0.64938
# 3                   1.45900  1.33095                   0.88521  0.66973
# 4                   1.32629  1.32261                   0.90563  0.63297
#
#    Trust (Government Corruption)  Generosity  Dystopia Residual  Year
# 0                        0.41978     0.29678            2.51738  2015
# ...

# %%
try1_df[(try1_df['Country'] ==   'Taiwan Province of China') | (try1_df['Country'] ==   'Hong Kong S.A.R., China') |
(try1_df['Country'] ==   'Mozambique') | (try1_df['Country'] ==   'Lesotho') |
(try1_df['Country'] ==   'Central African Republic') ]
# Out:
#                       Country              Region  Happiness Rank  \
# 93                 Mozambique  Sub-Saharan Africa              94
# 96                    Lesotho  Sub-Saharan Africa              97
# 147  Central African Republic  Sub-Saharan Africa             148
# 32   Taiwan Province of China        Eastern Asia              33
# 70    Hong Kong S.A.R., China        Eastern Asia              71
# 112                Mozambique  Sub-Saharan Africa             113
# 138                   Lesotho  Sub-Saharan Africa             139
# 154  Central African Republic  Sub-Saharan Africa             155
#
#      Happiness Score  Economy (GDP per Capita)    Family  \
# 93             4.971                  0.083080  1.026260
# 96             4.898                  0.375450  1.041030
# 147            3.678                  0.078500  0.000000
# 32             6.422                  1.433627  1.384565
# 70             5.472                  1.551675  1.262791
# ...

# %%
#now we have zero null

# %%
# go to clean them

# %% [markdown]
# #### 7. Check Accuracy:
#
# Verify that the data is correct and precise. This could involve comparing data samples with known sources or using validation rules.
#
# **The process includes:**
# 1. Validating the appropriateness of data types for the dataset.
# 2. Identifying outliers  using established validation  rule

# %%
# check columns types

# %%
try1_df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.39651  1.34951                   0.94143  0.66557
# 1                   1.30232  1.40223                   0.94784  0.62877
# 2                   1.32548  1.36058                   0.87464  0.64938
# 3                   1.45900  1.33095                   0.88521  0.66973
# 4                   1.32629  1.32261                   0.90563  0.63297
#
#    Trust (Government Corruption)  Generosity  Dystopia Residual  Year
# 0                        0.41978     0.29678            2.51738  2015
# ...

# %%
try1_df.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# Year                               int64
# dtype: object

# %%
#All types are correct

# %%
# check outliers

# %% [markdown]
# **What is an Outlier?**
# Outlier is an row/observation that appears far away and diverges from an overall pattern in a sample.
#
# **What are the types of Outliers?**
# 1. Univariate: These outliers can be found when we look at distribution of a single variable
# 2. Multivariate: are outliers in an n-dimensional space. In order to find them, you have to look at distributions in multi-dimensions. example (hight=100, weight=100) for a person
#
# **What causes Outliers?**
# Whenever we come across outliers, the ideal way to tackle them is to find out the reason of having these outliers. The method to deal with them would then depend on the reason of their occurrence.
#
# Let’s understand various types of outliers:
#
# 1. Data Entry Errors:- Human errors such as errors caused during data collection, recording, or entry can cause outliers in data.
# 2. Measurement Error: It is the most common source of outliers. This is caused when the measurement instrument used turns out to be faulty.
# 3. Data Processing Error: Whenever we perform data mining, we extract data from multiple sources. It is possible that some manipulation or extraction errors may lead to outliers in the dataset.
# 4. Sampling error: For instance, we have to measure the height of athletes. By mistake, we include a few basketball players in the sample. This inclusion is likely to cause outliers in the dataset.
# 5. Natural Outlier: When an outlier is not artificial (due to error), it is a natural outlier. For instance: In my last assignment with one of the renowned insurance company, I noticed that the performance of top 50 financial advisors was far higher than rest of the population. Surprisingly, it was not due to any error. Hence, whenever we perform any data mining activity with advisors, we used to treat this segment separately.
#
#
# **What is the impact of Outliers on a dataset?**
#
#
# ![image.png](https://www.analyticsvidhya.com/wp-content/uploads/2015/02/Outlier_31.png)
#
#
#
# **How to detect Outliers?**
#
# 1. Most commonly used method to detect outliers is visualization (Univariate Graphical Analysis).
#
# We use 3 common visualization methods:
# >- Box-plot: A box plot is a method for graphically depicting groups of numerical data through their quartiles. The box extends from the Q1 to Q3 quartile values of the data, with a line at the median (Q2). The whiskers extend from the edges of the box to show the range of the data. Outlier points are those past the end of the whiskers. Box plots show robust measures of location and spread as well as providing information about symmetry and outliers.
# >
# >
# >![image.png](https://miro.medium.com/v2/resize:fit:698/format:webp/1*VK5iHA2AB28HSZwWwUbNYg.png)
# >
# >
# >- Histogram
# >- Scatter Plot: A scatter plot is a mathematical diagram using Cartesian coordinates to display values for two variables for a set of data. The data are displayed as a collection of points, each having the value of one variable determining the position on the horizontal axis and the value of the other variable determining the position on the vertical axis. The points that are far from the population can be termed as an outlier.
# >
# >
# >![image.png](https://miro.medium.com/v2/resize:fit:4800/format:webp/1*Ov6aH-8yIwNoUxtMFwgx4g.png)
# >
# >
#
# 2. Using statistical method (Univariate Non-Graphical analysis):
# >- Any value, which is beyond the range of -1.5 x IQR to 1.5 x IQR
#
# ![image.png](https://www.whatissixsigma.net/wp-content/uploads/2015/07/Box-Plot-Diagram-to-identify-Outliers-figure-1.png)
#
# >- Use capping methods. Any value which out of range of 5th and 95th percentile can be considered as outlier
# >- Data points, three or more standard deviation away from mean are considered outlier: The Z-score is the signed number of standard deviations by which the value of an observation or data point is above the mean value of what is being observed or measured. While calculating the Z-score we re-scale and center the data and look for data points that are too far from zero. These data points which are way too far from zero will be treated as the outliers. In most of the cases, a threshold of 3 or -3 is used i.e if the Z-score value is greater than or less than 3 or -3 respectively, that data point will be identified as outliers.
# > - Outlier detection is merely a special case of the examination of data for influential data points and it also depends on the business understanding

# %%
# go to univariate graphical analysis
# go to lesson : data visualisation 1 - chart type section
# then go to univariate graphical analysis
# detect outliers using graphs varbaly

# %%
# go to lesson: statistics 1 then statistics 3
# then go to univariate Non graphical analysis
# detect outliers using numerical statistics

# %%
try1_df.head(3)
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.39651  1.34951                   0.94143  0.66557
# 1                   1.30232  1.40223                   0.94784  0.62877
# 2                   1.32548  1.36058                   0.87464  0.64938
#
#    Trust (Government Corruption)  Generosity  Dystopia Residual  Year
# 0                        0.41978     0.29678            2.51738  2015
# 1                        0.14145     0.43630            2.70201  2015
# 2                        0.48357     0.34139            2.49204  2015

# %%
# go to delete ouliers

# %% [markdown]
# ## 2. Data Cleaning:
#
# Preliminary findings from data profiling can lead to cleaning the data by:
# - Handling missing values
# - Correcting errors.
# - Dealing with outliers.
#
# -------------------

# %% [markdown]
# ### Handling missing values:

# %% [markdown]
# **Why my data has missing values?**
# They may occur at two stages:
# 1. Data Extraction: It is possible that there are problems with extraction process. Errors at data extraction stage are typically easy to find and can be corrected easily as well.
# 2. Data collection: These errors occur at time of data collection and are harder to correct.
#
# **Why do we need to handle the missing data?**
# To avoid:
# - Bias the conclusions.
# - Leading the business to make wrong decisions.
#
# **Which are the methods to treat missing values ?**
# 1. Deletion: we delete rows where any of the variable is missing. Simplicity is one of the major advantage of this method, but this method reduces the power of model because it reduces the sample size.
#
# 2. Imputation: is a method to fill in the missing values with estimated ones. This imputation is one of the most frequently used methods.
#
#     2.1. Mean/ Mode/ Median Imputation: It consists of replacing the missing data for a given attribute by the mean or median (quantitative attribute) or mode (qualitative attribute) of all known values of that variable.
#     > It can be of two types:
#     > - Generalized Imputation: In this case, we calculate the mean or median for all non missing values of that variable then replace missing value with mean or median.
#     > - Similar case Imputation: In this case, we calculate average for each group individually of non missing values then replace the missing value based on the group.
#
#     2.2. Constant Value
#
#     2.3. Forward Filling
#
#     2.4. Backward Filling
#
# 6. Prediction Model:  Prediction model is one of the sophisticated method for handling missing data. Here, we create a predictive model to estimate values that will substitute the missing data.  In this case, we divide our data set into two sets: One set with no missing values for the variable and another one with missing values. First data set become training data set of the model while second data set with missing values is test data set and variable with missing values is treated as target variable. Next, we create a model to predict target variable based on other attributes of the training data set and populate missing values of test data set.
#
# > There are 2 drawbacks for this approach:
# > - The model estimated values are usually more well-behaved than the true values
# > - If there are no relationships with attributes in the data set and the attribute with missing values, then the model will not be precise for estimating missing values.
#
# 9. KNN Imputation: In this method of imputation, the missing values of an attribute are imputed using the given number of attributes that are most similar to the attribute whose values are missing. The similarity of two attributes is determined using a distance function. It is also known to have certain advantage & disadvantages.
#
#    > **Advantages:**
#    > - k-nearest neighbour can predict both qualitative & quantitative attributes
#    > - Creation of predictive model for each attribute with missing data is not required
#    > - Attributes with multiple missing values can be easily treated
#    > - Correlation structure of the data is taken into consideration
#
#    > **Disadvantage:**
#    > - KNN algorithm is very time-consuming in analyzing large database. It searches through all the dataset looking for the most similar instances.
#    > - Choice of k-value is very critical. Higher value of k would include attributes which are significantly different from what we need whereas lower value of k implies missing out of significant attributes.
#
# --------------------

# %%
# go back to 6th dimention --> Completeness

# %% [markdown]
# ### Correcting errors
#
# -------------------

# %%
# go back to 7th dimension Accuracy

# %% [markdown]
# ### Dealing with outliers:

# %% [markdown]
# **How to remove Outliers?**
# Most of the ways to deal with outliers are similar to the methods of missing values like deleting rows, transforming them, binning them, treat them as a separate group, imputing values and other statistical methods. Here, we will discuss the common techniques used to deal with outliers:
#
# 1. Deleting rows: We delete outlier values if it is due to data entry error, data processing error or outlier rows are very small in numbers. We can also use trimming at both ends to remove outliers.
#
# 2. Imputing: Like imputation of missing values, we can also impute outliers. We can use mean, median, mode imputation methods. Before imputing values, we should analyse if it is natural outlier or artificial. If it is artificial, we can go with imputing values. We can also use statistical model to predict values of outlier rows and after that we can impute it with predicted values.
#
# 3. Treat separately: If there are significant number of outliers, we should treat them separately in the statistical model. One of the approach is to treat both groups as two different groups and build individual model for both groups and then combine the output.

# %%
try1_df.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# Year                               int64
# dtype: object

# %%
try1_df.head(2)
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.39651  1.34951                   0.94143  0.66557
# 1                   1.30232  1.40223                   0.94784  0.62877
#
#    Trust (Government Corruption)  Generosity  Dystopia Residual  Year
# 0                        0.41978     0.29678            2.51738  2015
# 1                        0.14145     0.43630            2.70201  2015

# %% [markdown]
# ## 3. Univariate Analysis:
#
# This involves examining single variables to understand their characteristics (distribution, central tendency, dispersion, and shape).
#
# We calculate **numerical values** about the data that tells us about the distribution of the data. We also **draw graphs** showing visually how the data is distributed. **To answer the following questions about Features/characteristics of Data:**
# - Where is the center of the data? (location)
# - How much does the data vary? (scale)
# - What is the shape of the data? (shape)
#
# **The benefits of this analysis:**
# Statistics summary gives a high-level idea to identify whether the data has any outliers, data entry error, distribution of data such as the data is normally distributed or left/right skewed
#
# **In this step, we will explore variables one by one using following approaches:**

# %% [markdown]
# ### 1. Univariate Graphical Analysis:
# Method to perform uni-variate analysis will depend on whether the variable type is categorical or numerical.

# %%
try1_df_to_2015 = try1_df[try1_df['Year']==2015]

# %%
top_reg_counts = try1_df["Region"].value_counts().head(10)
top_reg_counts
#try1_df.columns
# Out:
# Region
# Sub-Saharan Africa                 117
# Central and Eastern Europe          87
# Latin America and Caribbean         68
# Western Europe                      63
# Middle East and Northern Africa     58
# Southeastern Asia                   26
# Southern Asia                       21
# Eastern Asia                        18
# North America                        6
# Australia and New Zealand            6
# Name: count, dtype: int64

# %%
try1_df.shape
# Out:
# (470, 12)

# %%
try1_df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Trust (Government Corruption)', 'Generosity',
#        'Dystopia Residual', 'Year'],
#       dtype='object')

# %%
try1_df.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# Year                               int64
# dtype: object

# %% [markdown]
# #### I. Categorical Variables:
#
# we’ll use frequency table to understand distribution of each category
# - Bar Chart (Ordinal) - Orderd
# - Pie Chart (Nominal) - non Orderd

# %%
top_reg_counts_df = top_reg_counts.to_frame().reset_index()
top_reg_counts_df.columns = ['Region', 'Happiness Score']
sns.barplot(y="Region", x="Happiness Score", data=top_reg_counts_df)
plt.title('IN all years(2015, 2016,2017)')
plt.show()

# %%
try1_df_to_2015
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Economy (GDP per Capita)   Family  \
# 0              7.587                   1.39651  1.34951
# 1              7.561                   1.30232  1.40223
# ...

# %%
try1_df_to_2015 = try1_df[try1_df['Year']==2015]
top_reg_counts2015 = try1_df_to_2015["Region"].value_counts()

top_reg_counts_df2015 = top_reg_counts2015.to_frame().reset_index()
top_reg_counts_df2015.columns = ['Region', 'Happiness Score']
sns.barplot(y="Region", x="Happiness Score", data=top_reg_counts_df2015)
plt.title('IN year 2015')
plt.show()

# %%
try1_df_to_2016 = try1_df[try1_df['Year']==2016]
top_reg_counts2016 = try1_df_to_2016["Region"].value_counts()

top_reg_counts_df2016 = top_reg_counts2016.to_frame().reset_index()
top_reg_counts_df2016.columns = ['Region', 'Happiness Score']
sns.barplot(y="Region", x="Happiness Score", data=top_reg_counts_df2016)
plt.title('IN year 2016')
plt.show()

# %%
try1_df_to_2017 = try1_df[try1_df['Year']==2017]
top_reg_counts2017 = try1_df_to_2017["Region"].value_counts()

top_reg_counts_df2017 = top_reg_counts2017.to_frame().reset_index()
top_reg_counts_df2017.columns = ['Region', 'Happiness Score']
sns.barplot(y="Region", x="Happiness Score", data=top_reg_counts_df2017)

plt.title('IN year 2017')
plt.show()

# %%
plt.figure(figsize=(30,20))
sns.countplot(data=try1_df,
              x="Region")
plt.title("Number of countries per region",fontsize=40)
plt.ylabel("Number of countries",fontsize=40)
plt.xlabel("Region",fontsize=40)
plt.show()

# %%
plt.figure(figsize=(30,20))
sns.countplot(data=try1_df[try1_df['Year'] == 2015],
              x="Region")

plt.title("Number of countries per region in 2015",fontsize=40)
plt.ylabel("Number of countries",fontsize=40)
plt.xlabel("Region",fontsize=40)
plt.show()

# %%
plt.figure(figsize=(30,20))
sns.countplot(data=try1_df[try1_df['Year'] == 2016],
              x="Region")

plt.title("Number of countries per region in 2016",fontsize=40)
plt.ylabel("Number of countries",fontsize=40)
plt.xlabel("Region",fontsize=40)
plt.show()

# %%
plt.figure(figsize=(30,20))
sns.countplot(data=try1_df[try1_df['Year'] == 2017],
              x="Region")

plt.title("Number of countries per region in 2017",fontsize=40)
plt.ylabel("Number of countries",fontsize=40)
plt.xlabel("Region",fontsize=40)
plt.show()

# %% [markdown]
# #### II. Numerical Variables:
#
# we need to understand the central tendency and spread of the variable (Descriptive Analysis) using:
#    - Box plot
#    - Histogram

# %%
try1_df.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# Year                               int64
# dtype: object

# %%
plt.hist(try1_df['Happiness Score'],
         bins = 40
        )
plt.xlabel('Happiness Score')
plt.ylabel('Frequency')
plt.title(f'Happiness Score')
plt.show()

# %%
plt.hist(try1_df['Economy (GDP per Capita)'],
         bins = 40
        ) 
plt.xlabel('Economy (GDP per Capita)')
plt.ylabel('Frequency')
plt.title(f'Economy (GDP per Capita)')
plt.show()

# %%
plt.hist(try1_df['Family'],
         bins = 40
        ) 
plt.xlabel('Family ')
plt.ylabel('Frequency')
plt.title(f'Family')
plt.show()

# %%
plt.hist(try1_df['Health (Life Expectancy)'],
         bins = 40
        ) 
plt.xlabel('Health (Life Expectancy)')
plt.ylabel('Frequency')
plt.title(f'Health (Life Expectancy)')
plt.show()

# %%
plt.hist(try1_df['Freedom'],
         bins = 40
        ) 
plt.xlabel('Freedom')
plt.ylabel('Frequency')
plt.title(f'Freedom')
plt.show()

# %%
plt.hist(try1_df['Trust (Government Corruption)'],
         bins = 40
        ) 
plt.xlabel('Trust (Government Corruption)')
plt.ylabel('Frequency')
plt.title(f'Trust (Government Corruption)')
plt.show()

# %%
plt.hist(try1_df['Generosity'],
         bins = 40
        ) 
plt.xlabel('Generosity')
plt.ylabel('Frequency')
plt.title(f'Generosity')
plt.show()

# %%
plt.hist(try1_df['Dystopia Residual'],
         bins = 40
        ) 
plt.xlabel('Dystopia Residual')
plt.ylabel('Frequency')
plt.title(f'Freedom')
plt.show()

# %%
try1_df
# Out:
#                       Country                           Region  \
# 0                 Switzerland                   Western Europe
# 1                     Iceland                   Western Europe
# 2                     Denmark                   Western Europe
# 3                      Norway                   Western Europe
# 4                      Canada                    North America
# ..                        ...                              ...
# 150                    Rwanda               Sub-Saharan Africa
# 151                     Syria  Middle East and Northern Africa
# 152                  Tanzania               Sub-Saharan Africa
# 153                   Burundi               Sub-Saharan Africa
# 154  Central African Republic               Sub-Saharan Africa
#
#      Happiness Rank  Happiness Score  Economy (GDP per Capita)    Family  \
# 0                 1            7.587                  1.396510  1.349510
# ...

# %%
plt.figure(figsize=(20, 20))

sns.boxplot(
    data=try1_df,
    x="Region",
    y="Happiness Score",
    hue="Year"
)
plt.title("Distribution of Happiness Scores by Region and Year", fontsize=20)
plt.ylabel("Happiness Score", fontsize=18)
plt.xlabel("Region", fontsize=18)
plt.xticks(rotation=90, fontsize=14)
plt.yticks(fontsize=14)
plt.legend(title="Year")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 2. Univariate Non-Graphical analysis:
#
# - Where is the center of the data? (location) --> **Measures of central tendency**
# - How much does the data vary? (scale) --> **Measure of variability**
# - What is the shape of the data? (shape) --> **Measures of variation combined with an average (measure of center) gives a good picture of the distribution of the data.**

# %%
try1_df.describe().T
# Out:
#                                count         mean        std         min  \
# Happiness Rank                 470.0    78.829787  45.281408     1.00000
# Happiness Score                470.0     5.370728   1.136998     2.69300
# Economy (GDP per Capita)       470.0     0.927830   0.415584     0.00000
# Family                         470.0     0.990347   0.318707     0.00000
# Health (Life Expectancy)       470.0     0.579968   0.240161     0.00000
# Freedom                        470.0     0.402828   0.150356     0.00000
# Trust (Government Corruption)  470.0     0.134790   0.111313     0.00000
# Generosity                     470.0     0.242241   0.131543     0.00000
# Dystopia Residual              470.0     2.092717   0.565772     0.32858
# Year                           470.0  2015.993617   0.816907  2015.00000
#
#                                        25%          50%          75%  \
# Happiness Rank                   40.000000    79.000000   118.000000
# ...

# %%
try1_df.describe(include='object').T
# Out:
#         count unique                 top freq
# Country   470    166         Switzerland    3
# Region    470     10  Sub-Saharan Africa  117

# %%
print(round(try1_df['Happiness Score'].mean(),2))
print(round(try1_df['Happiness Score'].std(),2))
# Out:
# 5.37
# 1.14

# %%
print(round(try1_df['Economy (GDP per Capita)'].mean(),2))
print(round(try1_df['Economy (GDP per Capita)'].std(),2))
# Out:
# 0.93
# 0.42

# %%
print(round(try1_df['Family'].mean(),2))
print(round(try1_df['Family'].std(),2))
# Out:
# 0.99
# 0.32

# %%
print(round(try1_df['Health (Life Expectancy)'].mean(),2))
print(round(try1_df['Health (Life Expectancy)'].std(),2))
# Out:
# 0.58
# 0.24

# %%
print(round(try1_df['Freedom'].mean(),2))
print(round(try1_df['Freedom'].std(),2))
# Out:
# 0.4
# 0.15

# %%
print(round(try1_df['Trust (Government Corruption)'].mean(),2))
print(round(try1_df['Trust (Government Corruption)'].std(),2))
# Out:
# 0.13
# 0.11

# %%
print(round(try1_df['Generosity'].mean(),2))
print(round(try1_df['Generosity'].std(),2))
# Out:
# 0.24
# 0.13

# %%
print(round(try1_df['Dystopia Residual'].mean(),2))
print(round(try1_df['Dystopia Residual'].std(),2))
# Out:
# 2.09
# 0.57

# %% [markdown]
# ## 4. Bivariate/Multivariate Analysis:
#
# Here, you look at the relationships between two or more variables. This can involve looking for correlations, patterns, and trends that suggest a relationship or an association.
#
# We can perform bi-variate analysis for any combination of categorical and numerical variables. The combination can be:
# | bi-variate variables   | Plot type |
# | ------------- | ------------- |
# | Categorical & Categorical| Stacked Bar Chart |
# | Categorical & numerical  | scatter plot, histogram, box plot|
# | numerical  & numerical  | Scatter plot, line chart|
#
#
# Multivariate Analysis:
# - Heat map
# - Bar Chart
# - Scatter Chart
# - Line Chart

# %% [markdown]
# **Categorical & Categorical --> (Stacked Column Chart)**

# %%
try1_df
# Out:
#                       Country                           Region  \
# 0                 Switzerland                   Western Europe
# 1                     Iceland                   Western Europe
# 2                     Denmark                   Western Europe
# 3                      Norway                   Western Europe
# 4                      Canada                    North America
# ..                        ...                              ...
# 150                    Rwanda               Sub-Saharan Africa
# 151                     Syria  Middle East and Northern Africa
# 152                  Tanzania               Sub-Saharan Africa
# 153                   Burundi               Sub-Saharan Africa
# 154  Central African Republic               Sub-Saharan Africa
#
#      Happiness Rank  Happiness Score  Economy (GDP per Capita)    Family  \
# 0                 1            7.587                  1.396510  1.349510
# ...

# %% [markdown]
# **Categorical & numerical --> (scatter plot, histogram, box plot)**

# %% [markdown]
# **numerical & numerical --> (Scatter plot, line chart)**

# %%
# Create a scatter plot
sns.scatterplot(y='Happiness Rank', x='Freedom',
                #hue='Year',
                data=try1_df)



# Show the plot
plt.show()

# %%
# Create a scatter plot
sns.scatterplot(y='Happiness Rank', x='Family',
                #hue='Year',
                data=try1_df)



# Show the plot
plt.show()

# %% [markdown]
# We could also use a correlation matrix to get more specific information about the relationship between these two variables.

# %%
corr_matrix = try1_df.select_dtypes(include=np.number).corr()
corr_matrix
# Out:
#                                Happiness Rank  Happiness Score  \
# Happiness Rank                       1.000000        -0.993268
# Happiness Score                     -0.993268         1.000000
# Economy (GDP per Capita)            -0.790551         0.785450
# Family                              -0.637627         0.636532
# Health (Life Expectancy)            -0.750146         0.748040
# Freedom                             -0.547627         0.560353
# Trust (Government Corruption)       -0.384371         0.406340
# Generosity                          -0.146162         0.163562
# Dystopia Residual                   -0.482706         0.489747
# Year                                -0.013460        -0.007761
#
#                                Economy (GDP per Capita)    Family  \
# Happiness Rank                                -0.790551 -0.637627
# Happiness Score                                0.785450  0.636532
# Economy (GDP per Capita)                       1.000000  0.585449
# ...

# %%
# Create the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix,
            annot=True, 
            cmap='coolwarm',
            fmt=".2g"
           )

# Show the plot
plt.show()

# %%
#Q1

# %%
try1_df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Trust (Government Corruption)', 'Generosity',
#        'Dystopia Residual', 'Year'],
#       dtype='object')

# %%
#by country
# Set the style of the visualization
sns.set(style="whitegrid")

# the list of factors 
factors = ['Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
           'Freedom', 'Trust (Government Corruption)', 'Generosity']

# to work by year
years = try1_df['Year'].unique()

# Create a figure for each year and each factor
fig, axes = plt.subplots(len(years) * (len(factors) + 1), 1, figsize=(12, 4 * len(years) * (len(factors) + 1)), sharex=True)

# Ensure axes is always iterable, even if there's only one subplot
if len(years) * (len(factors) + 1) == 1:
    axes = [axes]

# Plot top countries by overall happiness for each year
for year_index, year in enumerate(years):
    year_df = try1_df[try1_df['Year'] == year]
    
    # Overall happiness
    top_happiness = year_df[['Country', 'Happiness Score']].sort_values(by='Happiness Score', ascending=False).head(10)
    sns.barplot(x='Happiness Score', y='Country', data=top_happiness, ax=axes[year_index * (len(factors) + 1)], palette='viridis')
    axes[year_index * (len(factors) + 1)].set_title(f'Top 10 Countries by Overall Happiness in {year}')
    axes[year_index * (len(factors) + 1)].set_xlabel('Happiness Score')
    axes[year_index * (len(factors) + 1)].set_ylabel('Country')

    # Factors
    for factor_index, factor in enumerate(factors):
        top_factor = year_df[['Country', factor]].sort_values(by=factor, ascending=False).head(10)
        sns.barplot(x=factor, y='Country', data=top_factor, ax=axes[year_index * (len(factors) + 1) + factor_index + 1], palette='viridis')
        axes[year_index * (len(factors) + 1) + factor_index + 1].set_title(f'Top 10 Countries by {factor} in {year}')
        axes[year_index * (len(factors) + 1) + factor_index + 1].set_xlabel(factor)
        axes[year_index * (len(factors) + 1) + factor_index + 1].set_ylabel('Country')


plt.tight_layout()
plt.show()
# Out:
# C:\Users\foooo\AppData\Local\Temp\ipykernel_31320\3839137041.py:24: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Happiness Score', y='Country', data=top_happiness, ax=axes[year_index * (len(factors) + 1)], palette='viridis')
# C:\Users\foooo\AppData\Local\Temp\ipykernel_31320\3839137041.py:32: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=factor, y='Country', data=top_factor, ax=axes[year_index * (len(factors) + 1) + factor_index + 1], palette='viridis')
# C:\Users\foooo\AppData\Local\Temp\ipykernel_31320\3839137041.py:32: FutureWarning:
#
# ...

# %%
#by country
# Set the style of the visualization
sns.set(style="whitegrid")

# the list of factors 
factors = ['Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
           'Freedom', 'Trust (Government Corruption)', 'Generosity']

# to work by year
years = try1_df['Year'].unique()

# Create a figure for each year and each factor
fig, axes = plt.subplots(len(years) * (len(factors) + 1), 1, figsize=(12, 4 * len(years) * (len(factors) + 1)), sharex=True)

# Ensure axes is always iterable, even if there's only one subplot
if len(years) * (len(factors) + 1) == 1:
    axes = [axes]

# Plot top countries by overall happiness for each year
for year_index, year in enumerate(years):
    year_df = try1_df[try1_df['Year'] == year]
    
    # Overall happiness
    top_happiness = year_df[['Region', 'Happiness Score']].sort_values(by='Happiness Score', ascending=False).head(10)
    sns.barplot(x='Happiness Score', y='Region', data=top_happiness, ax=axes[year_index * (len(factors) + 1)], palette='viridis')
    axes[year_index * (len(factors) + 1)].set_title(f'Top 10 Countries by Overall Happiness in {year}')
    axes[year_index * (len(factors) + 1)].set_xlabel('Happiness Score')
    axes[year_index * (len(factors) + 1)].set_ylabel('Region')

    # Factors
    for factor_index, factor in enumerate(factors):
        top_factor = year_df[['Region', factor]].sort_values(by=factor, ascending=False).head(10)
        sns.barplot(x=factor, y='Region', data=top_factor, ax=axes[year_index * (len(factors) + 1) + factor_index + 1], palette='viridis')
        axes[year_index * (len(factors) + 1) + factor_index + 1].set_title(f'Top 10 Countries by {factor} in {year}')
        axes[year_index * (len(factors) + 1) + factor_index + 1].set_xlabel(factor)
        axes[year_index * (len(factors) + 1) + factor_index + 1].set_ylabel('Region')


plt.tight_layout()
plt.show()
# Out:
# C:\Users\foooo\AppData\Local\Temp\ipykernel_31320\213666285.py:25: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Happiness Score', y='Region', data=top_happiness, ax=axes[year_index * (len(factors) + 1)], palette='viridis')
# C:\Users\foooo\AppData\Local\Temp\ipykernel_31320\213666285.py:33: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=factor, y='Region', data=top_factor, ax=axes[year_index * (len(factors) + 1) + factor_index + 1], palette='viridis')
# C:\Users\foooo\AppData\Local\Temp\ipykernel_31320\213666285.py:33: FutureWarning:
#
# ...

# %%
#Q2

# %%
df_2015 = try1_df[try1_df['Year'] == 2015][['Country', 'Happiness Score']]
df_2016 = try1_df[try1_df['Year'] == 2016][['Country', 'Happiness Score']]
df_2017 = try1_df[try1_df['Year'] == 2017][['Country', 'Happiness Score']]


# Merge data to compare changes
df_2015_2016 = pd.merge(df_2015, df_2016, on='Country', suffixes=('_2015', '_2016'))
df_2016_2017 = pd.merge(df_2016, df_2017, on='Country', suffixes=('_2016', '_2017'))

# Calculate the changes in scores
df_2015_2016['Score_Change'] = df_2015_2016['Happiness Score_2016'] - df_2015_2016['Happiness Score_2015']
df_2016_2017['Score_Change'] = df_2016_2017['Happiness Score_2017'] - df_2016_2017['Happiness Score_2016']

# Plotting the changes
plt.figure(figsize=(14, 6))

# Plot for 2015 to 2016
plt.subplot(1, 2, 1)
sns.barplot(x='Score_Change', y='Country', data=df_2015_2016, palette='viridis')
plt.title('Happiness Score Change from 2015 to 2016')
plt.xlabel('Change in Happiness Score')
plt.ylabel('Country')

# Plot for 2016 to 2017
plt.subplot(1, 2, 2)
sns.barplot(x='Score_Change', y='Country', data=df_2016_2017, palette='viridis')
plt.title('Happiness Score Change from 2016 to 2017')
plt.xlabel('Change in Happiness Score')
plt.ylabel('Country')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\foooo\AppData\Local\Temp\ipykernel_31320\2258857128.py:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Score_Change', y='Country', data=df_2015_2016, palette='viridis')
# C:\Users\foooo\AppData\Local\Temp\ipykernel_31320\2258857128.py:26: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Score_Change', y='Country', data=df_2016_2017, palette='viridis')

# %%
# Filter data for the years of interest
df_2015 = try1_df[try1_df['Year'] == 2015][['Country', 'Happiness Score']]
df_2016 = try1_df[try1_df['Year'] == 2016][['Country', 'Happiness Score']]
df_2017 = try1_df[try1_df['Year'] == 2017][['Country', 'Happiness Score']]

# Merge data to compare changes
df_2015_2016 = pd.merge(df_2015, df_2016, on='Country', suffixes=('_2015', '_2016'))
df_2016_2017 = pd.merge(df_2016, df_2017, on='Country', suffixes=('_2016', '_2017'))

# Calculate the changes in scores
df_2015_2016['Score_Change'] = df_2015_2016['Happiness Score_2016'] - df_2015_2016['Happiness Score_2015']
df_2016_2017['Score_Change'] = df_2016_2017['Happiness Score_2017'] - df_2016_2017['Happiness Score_2016']

# Plotting the changes
plt.figure(figsize=(14, 6))

# Plot for 2015 to 2016
plt.subplot(1, 2, 1)
sns.barplot(x='Score_Change', y='Country', data=df_2015_2016.head(15), palette='viridis')
plt.title('Happiness Score Change from 2015 to 2016')
plt.xlabel('Change in Happiness Score')
plt.ylabel('Country')

# Plot for 2016 to 2017
plt.subplot(1, 2, 2)
sns.barplot(x='Score_Change', y='Country', data=df_2016_2017.head(15), palette='viridis')
plt.title('Happiness Score Change from 2016 to 2017')
plt.xlabel('Change in Happiness Score')
plt.ylabel('Country')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\foooo\AppData\Local\Temp\ipykernel_31320\3108225557.py:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Score_Change', y='Country', data=df_2015_2016.head(15), palette='viridis')
# C:\Users\foooo\AppData\Local\Temp\ipykernel_31320\3108225557.py:26: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Score_Change', y='Country', data=df_2016_2017.head(15), palette='viridis')

# %%
# Filter data for the years of interest
df_2015 = try1_df[try1_df['Year'] == 2015][['Country', 'Happiness Score']]
df_2016 = try1_df[try1_df['Year'] == 2016][['Country', 'Happiness Score']]
df_2017 = try1_df[try1_df['Year'] == 2017][['Country', 'Happiness Score']]

# Merge data to compare changes
df_2015_2016 = pd.merge(df_2015, df_2016, on='Country', suffixes=('_2015', '_2016'))
df_2016_2017 = pd.merge(df_2016, df_2017, on='Country', suffixes=('_2016', '_2017'))

# Calculate the changes in scores
df_2015_2016['Score_Change'] = df_2015_2016['Happiness Score_2016'] - df_2015_2016['Happiness Score_2015']
df_2016_2017['Score_Change'] = df_2016_2017['Happiness Score_2017'] - df_2016_2017['Happiness Score_2016']

# Plotting the changes
plt.figure(figsize=(15, 60))

# Plot for 2015 to 2016
plt.subplot(1, 2, 1)
sns.barplot(x='Score_Change', y='Country', data=df_2015_2016, palette='viridis')
plt.title('Happiness Score Change from 2015 to 2016')
plt.xlabel('Change in Happiness Score')
plt.ylabel('Country')

# Plot for 2016 to 2017
plt.subplot(1, 2, 2)
sns.barplot(x='Score_Change', y='Country', data=df_2016_2017, palette='viridis')
plt.title('Happiness Score Change from 2016 to 2017')
plt.xlabel('Change in Happiness Score')
plt.ylabel('Country')
#plt.xticks(fontsize=14)  
#plt.yticks(fontsize=60) 
plt.tight_layout()
plt.show()
# Out:
# C:\Users\foooo\AppData\Local\Temp\ipykernel_31320\4001664769.py:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Score_Change', y='Country', data=df_2015_2016, palette='viridis')
# C:\Users\foooo\AppData\Local\Temp\ipykernel_31320\4001664769.py:26: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Score_Change', y='Country', data=df_2016_2017, palette='viridis')

# %%
َ#Q3

# %%
df_2015_2016_nonzero = df_2015_2016[df_2015_2016['Score_Change'] != 0]
df_2016_2017_nonzero = df_2016_2017[df_2016_2017['Score_Change'] != 0]

# %%
df_2015_2016 = pd.merge(df_2015, df_2016, on='Country', suffixes=('_2015', '_2016'))
df_2016_2017 = pd.merge(df_2016, df_2017, on='Country', suffixes=('_2016', '_2017'))

df_2015_2016['Score_Change'] = df_2015_2016['Happiness Score_2016'] - df_2015_2016['Happiness Score_2015']
df_2016_2017['Score_Change'] = df_2016_2017['Happiness Score_2017'] - df_2016_2017['Happiness Score_2016']


df_2015_2016_nonzero = df_2015_2016[df_2015_2016['Score_Change'] != 0]
df_2016_2017_nonzero = df_2016_2017[df_2016_2017['Score_Change'] != 0]


df_2015_2016_sorted = df_2015_2016_nonzero.sort_values(by='Score_Change', ascending=False)
df_2016_2017_sorted = df_2016_2017_nonzero.sort_values(by='Score_Change', ascending=False)

# print("The change between 2015 & 2016 in dec")
# print(df_2015_2016[['Country', 'Score_Change']].head())

# print("The change between 2015 & 2016 in inc")
# print(df_2015_2016[['Country', 'Score_Change']].tail())

# print("The change between 2015 & 2016 in dec")
# print(df_2016_2017[['Country', 'Score_Change']].head())

# print("The change between 2015 & 2016 in inc")
# print(df_2016_2017[['Country', 'Score_Change']].tail())

# %%
df_2015_2016_sorted
# Out:
#        Country  Happiness Score_2015  Happiness Score_2016  Score_Change
# 66     Algeria                 5.605                 6.355         0.750
# 150       Togo                 2.839                 3.303         0.464
# 87      Latvia                 5.098                 5.560         0.462
# 84     Romania                 5.124                 5.528         0.404
# 98     Hungary                 4.800                 5.145         0.345
# ..         ...                   ...                   ...           ...
# 112      Sudan                 4.550                 4.139        -0.411
# 109   Zimbabwe                 4.610                 4.193        -0.417
# 113      Haiti                 4.518                 4.028        -0.490
# 21   Venezuela                 6.810                 6.084        -0.726
# 110    Liberia                 4.571                 3.622        -0.949
#
# [146 rows x 4 columns]

# %%
print("The change between 2015 & 2016 in dec")
print(df_2015_2016_sorted[['Country', 'Score_Change']].head())
print('-------------------------------------------')
print("The change between 2015 & 2016 in inc")
print(df_2015_2016_sorted[['Country', 'Score_Change']].tail())
# Out:
# The change between 2015 & 2016 in dec
#      Country  Score_Change
# 66   Algeria         0.750
# 150     Togo         0.464
# 87    Latvia         0.462
# 84   Romania         0.404
# 98   Hungary         0.345
# -------------------------------------------
# The change between 2015 & 2016 in inc
#        Country  Score_Change
# 112      Sudan        -0.411
# 109   Zimbabwe        -0.417
# 113      Haiti        -0.490
# 21   Venezuela        -0.726
# 110    Liberia        -0.949

# %%
print("The change between 2016 & 2017 in dec")
print(df_2016_2017_sorted[['Country', 'Score_Change']].head())
print('-------------------------------------------')
print("The change between 2015 & 2017 in inc")
print(df_2016_2017_sorted[['Country', 'Score_Change']].tail())
# Out:
# The change between 2016 & 2017 in dec
#           Country  Score_Change
# 122      Bulgaria         0.497
# 146   Afghanistan         0.434
# 148         Syria         0.393
# 113         Egypt         0.373
# 109  South Africa         0.370
# -------------------------------------------
# The change between 2015 & 2017 in inc
#        Country  Score_Change
# 141   Tanzania        -0.317
# 124   Zimbabwe        -0.318
# 129      Haiti        -0.425
# 35     Algeria        -0.483
# 40   Venezuela        -0.834

# %%
df_2015_2017 = pd.merge(df_2015, df_2017, on='Country', suffixes=('_2015', '_2017'))

df_2015_2017['Score_Change'] = df_2015_2017['Happiness Score_2017'] - df_2015_2017['Happiness Score_2015']

df_2015_2017_nonzero = df_2016_2017[df_2016_2017['Score_Change'] != 0]
df_2015_2017_sorted = df_2015_2016_nonzero.sort_values(by='Score_Change', ascending=False)

print("The change between 2015 & 2017 dec:")
print(df_2015_2017_sorted[['Country', 'Score_Change']].head())
print('----------------------------------------------------')
print("The change between 2015 & 2017 inc:")
print(df_2015_2017_sorted[['Country', 'Score_Change']].tail())
# Out:
# The change between 2015 & 2017 dec:
#      Country  Score_Change
# 66   Algeria         0.750
# 150     Togo         0.464
# 87    Latvia         0.462
# 84   Romania         0.404
# 98   Hungary         0.345
# ----------------------------------------------------
# The change between 2015 & 2017 inc:
#        Country  Score_Change
# 112      Sudan        -0.411
# 109   Zimbabwe        -0.417
# 113      Haiti        -0.490
# 21   Venezuela        -0.726
# 110    Liberia        -0.949

# %%
# Bounce:

# %%
#Which country has the most fluctuated in happiness?

# %%
df_scores = try1_df[['Country', 'Year', 'Happiness Score']]

max_scores = df_scores.groupby('Country')['Happiness Score'].max()
min_scores = df_scores.groupby('Country')['Happiness Score'].min()

fluctuations = max_scores - min_scores

fluctuations_df = fluctuations.reset_index()
fluctuations_df.columns = ['Country', 'Score_Fluctuation']


most_fluctuating_country = fluctuations_df.loc[fluctuations_df['Score_Fluctuation'].idxmax()]

print("The country with the greatest fluctuated in happiness scores between 2015 and 2017:")
print(most_fluctuating_country)
# Out:
# The country with the greatest fluctuated in happiness scores between 2015 and 2017:
# Country              Venezuela
# Score_Fluctuation         1.56
# Name: 161, dtype: object

# %%
#In Which victor happend?

# %%
country_of_interest = 'Venezuela'

# Filter data for the specific country
df_country = try1_df[try1_df['Country'] == country_of_interest]


factors = ['Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)', 
               'Freedom', 'Trust (Government Corruption)', 'Generosity','Dystopia Residual']
    

df_country_factors = df_country[['Happiness Score'] + factors]

corr_matrix = df_country_factors.corr()

plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title(f'Correlation of Happiness Score with Factors for {country_of_interest}')
plt.show()
