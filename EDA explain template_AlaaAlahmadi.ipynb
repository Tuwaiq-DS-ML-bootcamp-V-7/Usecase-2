# %%
#Import all relevant libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import zscore
import os
## This statement allows the visuals to render within your Jupyter Notebook.
# %matplotlib inline

# %% [markdown]
# ## Loading the data
# We can now load the dataset into pandas using the read_csv() function. This converts the CSV file into a Pandas dataframe.

# %%
#Read in the csv file and convert to a Pandas dataframe
df = os.listdir('happiens')
df
# Out:
# ['2015.csv', '2016.csv', '2017.csv', '2018.csv', '2019.csv']

# %%
df_2015=pd.read_csv('happiens/2015.csv')

# %%
df_2016=pd.read_csv('happiens/2016.csv')

# %%
df_2017=pd.read_csv('happiens/2017.csv')

# %%
df_2018=pd.read_csv('happiens/2018.csv')

# %%
df_2019=pd.read_csv('happiens/2019.csv')

# %% [markdown]
# ### Viewing the dataframe
# We can get a quick sense of the size of our dataset by using the shape method. This returns a tuple with the number of rows and columns in the dataset.

# %%
df_2015.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
df_2016.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
# 3       Norway  Western Europe               4            7.498
# 4      Finland  Western Europe               5            7.413
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      7.460                      7.592
# 1                      7.428                      7.590
# 2                      7.333                      7.669
# 3                      7.421                      7.575
# 4                      7.351                      7.475
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.44178  1.16374                   0.79504  0.57941
# 1                   1.52733  1.14524                   0.86303  0.58557
# ...

# %%
df_2017.head()
# Out:
#        Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0       Norway               1            7.537      7.594445     7.479556
# 1      Denmark               2            7.522      7.581728     7.462272
# 2      Iceland               3            7.504      7.622030     7.385970
# 3  Switzerland               4            7.494      7.561772     7.426227
# 4      Finland               5            7.469      7.527542     7.410458
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 0                  1.616463  1.533524                  0.796667  0.635423
# 1                  1.482383  1.551122                  0.792566  0.626007
# 2                  1.480633  1.610574                  0.833552  0.627163
# 3                  1.564980  1.516912                  0.858131  0.620071
# 4                  1.443572  1.540247                  0.809158  0.617951
#
#    Generosity  Trust..Government.Corruption.  Dystopia.Residual
# ...

# %%
df_2018.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.632           1.305           1.592
# 1             2            Norway  7.594           1.456           1.582
# 2             3           Denmark  7.555           1.351           1.590
# 3             4           Iceland  7.495           1.343           1.644
# 4             5       Switzerland  7.487           1.420           1.549
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.874                         0.681       0.202
# 1                    0.861                         0.686       0.286
# 2                    0.868                         0.683       0.284
# 3                    0.914                         0.677       0.353
# 4                    0.927                         0.660       0.256
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.340
# ...

# %%
df_2019.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %% [markdown]
# ## 1. Data Profiling:
# Data profiling is a comprehensive process of examining the data available in an existing dataset and collecting statistics and information about that data.

# %%
#I use the 'info' function to find out the following:
'''
1-Number of columns and their names
2-Range index
3-Are there any null values ​​or not
4-And the data type in each column
'''

# %%
#Here we can see that there are no null values ​​either. 
#The first two columns are of type Object or String, the third is Integer, and then the rest are Float.

# %%
#here i can see there is no null and
df_2015.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
#number rows and column
df_2015.shape
# Out:
# (158, 12)

# %%
#to get statical info
df_2015.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %%
#to get name of column(header)
df_2015.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
#Here we can see that there are no null values ​​either. 
#The first two columns are of type Object or String, the third is Integer, and then the rest are Float.
df_2016.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 13 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        157 non-null    object
#  1   Region                         157 non-null    object
#  2   Happiness Rank                 157 non-null    int64
#  3   Happiness Score                157 non-null    float64
#  4   Lower Confidence Interval      157 non-null    float64
#  5   Upper Confidence Interval      157 non-null    float64
#  6   Economy (GDP per Capita)       157 non-null    float64
#  7   Family                         157 non-null    float64
#  8   Health (Life Expectancy)       157 non-null    float64
#  9   Freedom                        157 non-null    float64
#  10  Trust (Government Corruption)  157 non-null    float64
#  11  Generosity                     157 non-null    float64
# ...

# %%
df_2016.shape
# Out:
# (157, 13)

# %%
df_2016.describe()
# Out:
#        Happiness Rank  Happiness Score  Lower Confidence Interval  \
# count      157.000000       157.000000                 157.000000
# mean        78.980892         5.382185                   5.282395
# std         45.466030         1.141674                   1.148043
# min          1.000000         2.905000                   2.732000
# 25%         40.000000         4.404000                   4.327000
# 50%         79.000000         5.314000                   5.237000
# 75%        118.000000         6.269000                   6.154000
# max        157.000000         7.526000                   7.460000
#
#        Upper Confidence Interval  Economy (GDP per Capita)      Family  \
# count                 157.000000                157.000000  157.000000
# mean                    5.481975                  0.953880    0.793621
# std                     1.136493                  0.412595    0.266706
# min                     3.078000                  0.000000    0.000000
# ...

# %%
df_2016.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Lower Confidence Interval', 'Upper Confidence Interval',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Trust (Government Corruption)', 'Generosity',
#        'Dystopia Residual'],
#       dtype='object')

# %%
#Here we can see that there are no null values ​​either. 
#The first columns are of type Object or String, the secondis Integer, and then the rest are Float.
df_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 155 entries, 0 to 154
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        155 non-null    object
#  1   Happiness.Rank                 155 non-null    int64
#  2   Happiness.Score                155 non-null    float64
#  3   Whisker.high                   155 non-null    float64
#  4   Whisker.low                    155 non-null    float64
#  5   Economy..GDP.per.Capita.       155 non-null    float64
#  6   Family                         155 non-null    float64
#  7   Health..Life.Expectancy.       155 non-null    float64
#  8   Freedom                        155 non-null    float64
#  9   Generosity                     155 non-null    float64
#  10  Trust..Government.Corruption.  155 non-null    float64
#  11  Dystopia.Residual              155 non-null    float64
# ...

# %%
df_2017.shape
# Out:
# (155, 12)

# %%
df_2017.describe()
# Out:
#        Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# count      155.000000       155.000000    155.000000   155.000000
# mean        78.000000         5.354019      5.452326     5.255713
# std         44.888751         1.131230      1.118542     1.145030
# min          1.000000         2.693000      2.864884     2.521116
# 25%         39.500000         4.505500      4.608172     4.374955
# 50%         78.000000         5.279000      5.370032     5.193152
# 75%        116.500000         6.101500      6.194600     6.006527
# max        155.000000         7.537000      7.622030     7.479556
#
#        Economy..GDP.per.Capita.      Family  Health..Life.Expectancy.  \
# count                155.000000  155.000000                155.000000
# mean                   0.984718    1.188898                  0.551341
# std                    0.420793    0.287263                  0.237073
# min                    0.000000    0.000000                  0.000000
# ...

# %%
df_2017.columns
# Out:
# Index(['Country', 'Happiness.Rank', 'Happiness.Score', 'Whisker.high',
#        'Whisker.low', 'Economy..GDP.per.Capita.', 'Family',
#        'Health..Life.Expectancy.', 'Freedom', 'Generosity',
#        'Trust..Government.Corruption.', 'Dystopia.Residual'],
#       dtype='object')

# %%
#Here we can see that there are null values. 
df_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  156 non-null    int64
#  1   Country or region             156 non-null    object
#  2   Score                         156 non-null    float64
#  3   GDP per capita                156 non-null    float64
#  4   Social support                156 non-null    float64
#  5   Healthy life expectancy       156 non-null    float64
#  6   Freedom to make life choices  156 non-null    float64
#  7   Generosity                    156 non-null    float64
#  8   Perceptions of corruption     155 non-null    float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 11.1+ KB

# %%
df_2018.shape
# Out:
# (156, 9)

# %%
df_2018.describe()
# Out:
#        Overall rank       Score  GDP per capita  Social support  \
# count    156.000000  156.000000      156.000000      156.000000
# mean      78.500000    5.375917        0.891449        1.213237
# std       45.177428    1.119506        0.391921        0.302372
# min        1.000000    2.905000        0.000000        0.000000
# 25%       39.750000    4.453750        0.616250        1.066750
# 50%       78.500000    5.378000        0.949500        1.255000
# 75%      117.250000    6.168500        1.197750        1.463000
# max      156.000000    7.632000        2.096000        1.644000
#
#        Healthy life expectancy  Freedom to make life choices  Generosity  \
# count               156.000000                    156.000000  156.000000
# mean                  0.597346                      0.454506    0.181006
# std                   0.247579                      0.162424    0.098471
# min                   0.000000                      0.000000    0.000000
# ...

# %%
df_2018.columns
# Out:
# Index(['Overall rank', 'Country or region', 'Score', 'GDP per capita',
#        'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption'],
#       dtype='object')

# %%
#Here we can see that there are no null values ​​either. 
#The first columns are of type Integer, the second is object or string, and then the rest are Float.
df_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  156 non-null    int64
#  1   Country or region             156 non-null    object
#  2   Score                         156 non-null    float64
#  3   GDP per capita                156 non-null    float64
#  4   Social support                156 non-null    float64
#  5   Healthy life expectancy       156 non-null    float64
#  6   Freedom to make life choices  156 non-null    float64
#  7   Generosity                    156 non-null    float64
#  8   Perceptions of corruption     156 non-null    float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 11.1+ KB

# %%
df_2019.shape
# Out:
# (156, 9)

# %%
df_2019.describe()
# Out:
#        Overall rank       Score  GDP per capita  Social support  \
# count    156.000000  156.000000      156.000000      156.000000
# mean      78.500000    5.407096        0.905147        1.208814
# std       45.177428    1.113120        0.398389        0.299191
# min        1.000000    2.853000        0.000000        0.000000
# 25%       39.750000    4.544500        0.602750        1.055750
# 50%       78.500000    5.379500        0.960000        1.271500
# 75%      117.250000    6.184500        1.232500        1.452500
# max      156.000000    7.769000        1.684000        1.624000
#
#        Healthy life expectancy  Freedom to make life choices  Generosity  \
# count               156.000000                    156.000000  156.000000
# mean                  0.725244                      0.392571    0.184846
# std                   0.242124                      0.143289    0.095254
# min                   0.000000                      0.000000    0.000000
# ...

# %%
df_2019.columns
# Out:
# Index(['Overall rank', 'Country or region', 'Score', 'GDP per capita',
#        'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption'],
#       dtype='object')

# %% [markdown]
# The process of profiling differs slightly for categorical and numerical variables due to their inherent differences.
#
# **The two main types of data are:**
# - Quantitative (numerical) data
# - Qualitative (categorical) data

# %% [markdown]
# ### Data Quality Checks
# Data quality checks involve the process of ensuring that the data is accurate, complete, consistent, relevant, and reliable.
#
#
# **Here are typical steps involved in checking data quality:**

# %% [markdown]
# #### 1. Reliability:
# Evaluate the data's source and collection process to determine its trustworthiness.

# %%
#We took the data from the Kaggle website, which was the source of the Gallup global poll.
#title is:World Happiness Report

# %% [markdown]
# #### 2. Timeliness:
# Ensure the data is up-to-date and reflective of the current situation or the period of interest for the analysis.

# %%
#is not up to date >>> is only from 2015 to 2019

# %% [markdown]
# #### 3. Consistency:
#
# Confirm that the data is consistent within the dataset and across multiple data sources. For example, the same data point should not have different values in different places.

# %%
"""
This dataset contains several files. In my opinion, there is consistency as long as the similar columns in the different files 
contain the same information but with a slight difference in the column name, but this does not cause inconsistency.
"""
# Out:
# '\nThis dataset contains several files. In my opinion, there is consistency as long as the similar columns in the different files \ncontain the same information but with a slight difference in the column name, but this does not cause inconsistency.\n'

# %%
consistent_columns = {
    'Country': 'Country',
    'Happiness.Rank': 'Happiness Rank',
    'Happiness.Score': 'Happiness Score',
    'Economy..GDP.per.Capita.': 'Economy (GDP per Capita)',
    'Family': 'Family',
    'Health..Life.Expectancy.': 'Health (Life Expectancy)',
    'Freedom': 'Freedom',
    'Trust..Government.Corruption.': 'Trust (Government Corruption)',
    'Generosity': 'Generosity',
    'Dystopia.Residual': 'Dystopia Residual',
}

df_2017.rename(columns=consistent_columns, inplace=True)
df_2017
# Out:
#                       Country  Happiness Rank  Happiness Score  Whisker.high  \
# 0                      Norway               1            7.537      7.594445
# 1                     Denmark               2            7.522      7.581728
# 2                     Iceland               3            7.504      7.622030
# 3                 Switzerland               4            7.494      7.561772
# 4                     Finland               5            7.469      7.527542
# ..                        ...             ...              ...           ...
# 150                    Rwanda             151            3.471      3.543030
# 151                     Syria             152            3.462      3.663669
# 152                  Tanzania             153            3.349      3.461430
# 153                   Burundi             154            2.905      3.074690
# 154  Central African Republic             155            2.693      2.864884
#
# ...

# %% [markdown]
# #### 4. Relevance:
# Assess whether the data is appropriate and applicable for the intended analysis. Data that is not relevant can skew results and lead to incorrect conclusions.
#
# **Key considerations for relevance include:**
#
# > 1. Sample Appropriateness: Confirm that your data sample aligns with your analysis objectives. For instance, utilizing data from the Northern region will not yield accurate insights for the Western region of the Kingdom.
# >
# > 2. Variable Selection: Any column will not be relevant for our analysis, we can get rid of these using the drop() method. We will set the “axis” argument to 1 since we’re dealing with columns, and set the “inplace” argument to True to make the change permanent.

# %%
df_2015.drop(["Standard Error"],axis=1,inplace=True)

# %%
df_2015.drop(["Region"],axis=1,inplace=True)

# %%
df_2015
# Out:
#          Country  Happiness Rank  Happiness Score  Economy (GDP per Capita)  \
# 0    Switzerland               1            7.587                   1.39651
# 1        Iceland               2            7.561                   1.30232
# 2        Denmark               3            7.527                   1.32548
# 3         Norway               4            7.522                   1.45900
# 4         Canada               5            7.427                   1.32629
# ..           ...             ...              ...                       ...
# 153       Rwanda             154            3.465                   0.22208
# 154        Benin             155            3.340                   0.28665
# 155        Syria             156            3.006                   0.66320
# 156      Burundi             157            2.905                   0.01530
# 157         Togo             158            2.839                   0.20868
#
#       Family  Health (Life Expectancy)  Freedom  \
# ...

# %%
df_2016.drop(["Upper Confidence Interval"],axis=1,inplace=True)
df_2016.drop(["Lower Confidence Interval"],axis=1,inplace=True)

# %%
df_2016.drop(["Region"],axis=1,inplace=True)
df_2016
# Out:
#          Country  Happiness Rank  Happiness Score  Economy (GDP per Capita)  \
# 0        Denmark               1            7.526                   1.44178
# 1    Switzerland               2            7.509                   1.52733
# 2        Iceland               3            7.501                   1.42666
# 3         Norway               4            7.498                   1.57744
# 4        Finland               5            7.413                   1.40598
# ..           ...             ...              ...                       ...
# 152        Benin             153            3.484                   0.39499
# 153  Afghanistan             154            3.360                   0.38227
# 154         Togo             155            3.303                   0.28123
# 155        Syria             156            3.069                   0.74719
# 156      Burundi             157            2.905                   0.06831
#
#       Family  Health (Life Expectancy)  Freedom  \
# ...

# %%
df_2017.drop(["Whisker.high"],axis=1,inplace=True)

# %%
df_2017.drop(["Whisker.low"],axis=1,inplace=True)
df_2017
# Out:
#                       Country  Happiness Rank  Happiness Score  \
# 0                      Norway               1            7.537
# 1                     Denmark               2            7.522
# 2                     Iceland               3            7.504
# 3                 Switzerland               4            7.494
# 4                     Finland               5            7.469
# ..                        ...             ...              ...
# 150                    Rwanda             151            3.471
# 151                     Syria             152            3.462
# 152                  Tanzania             153            3.349
# 153                   Burundi             154            2.905
# 154  Central African Republic             155            2.693
#
#      Economy (GDP per Capita)    Family  Health (Life Expectancy)   Freedom  \
# 0                    1.616463  1.533524                  0.796667  0.635423
# ...

# %%
df_2015.drop(["Overall Rank"],axis=1,inplace=True)
df_2015
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 df_2015.drop(["Overall Rank"],axis=1,inplace=True)
#       2 df_2015
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
# ...

# %%
df_2015

# %%
df_2016.drop(["Overall Rank"],axis=1,inplace=True)
df_2016

# %%
df_2017.drop(["Overall Rank"],axis=1,inplace=True)
df_2017

# %%
df_2015['Year'] = 2015
df_2016['Year'] = 2016
df_2017['Year'] = 2017
df_2018['Year'] = 2018
df_2019['Year'] = 2019

# %% [markdown]
# #### 5. Uniqueness:
# Check for and remove duplicate records to prevent skewed analysis results.

# %% [markdown]
# **Here I was checking whether there was a duplicate in the rows or not and the answer is >>> NO <<<**

# %%
df_2015.duplicated().sum()
# Out:
# 0

# %%
df_2016.duplicated().sum()
# Out:
# 0

# %%
df_2017.duplicated().sum()
# Out:
# 0

# %%
df_2018.duplicated().sum()
# Out:
# 0

# %%
df_2019.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### 6. Completeness:
# Ensure that no critical data is missing. This might mean checking for null values or required fields that are empty.
#
# We will start by checking the dataset for missing or null values. For this, we can use the isna() method which returns a dataframe of boolean values indicating if a field is null or not. To group all missing values by column, we can include the sum() method.

# %% [markdown]
# **Here we started looking for whether there are null values ​​or not. As we can see, there are no null values ​​except in the 2018 dataset in the 'Perceptions of corruption'column.**

# %%
#Display number missing values per column
df_2015.isna().sum()
# Out:
# Country                          0
# Happiness Rank                   0
# Happiness Score                  0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
df_2016.isna().sum()
# Out:
# Country                          0
# Happiness Rank                   0
# Happiness Score                  0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
df_2017.isna().sum()
# Out:
# Country                          0
# Happiness Rank                   0
# Happiness Score                  0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Generosity                       0
# Trust (Government Corruption)    0
# Dystopia Residual                0
# dtype: int64

# %%
#here we have one null value
df_2018.isna().sum()
# Out:
# Overall rank                    0
# Country or region               0
# Score                           0
# GDP per capita                  0
# Social support                  0
# Healthy life expectancy         0
# Freedom to make life choices    0
# Generosity                      0
# Perceptions of corruption       1
# dtype: int64

# %% [markdown]
# **display rows that include null values:**

# %% [markdown]
# **I displayed the values ​​before and after the empty value in order to understand the column and try to find a pattern or repetition in the values:**

# %%
df_2018[df_2018['Perceptions of corruption'].isnull()]
# Out:
#     Overall rank     Country or region  Score  GDP per capita  Social support  \
# 19            20  United Arab Emirates  6.774           2.096           0.776
#
#     Healthy life expectancy  Freedom to make life choices  Generosity  \
# 19                     0.67                         0.284       0.186
#
#     Perceptions of corruption
# 19                        NaN

# %%
df_2018[0:30]
# Out:
#     Overall rank     Country or region  Score  GDP per capita  Social support  \
# 0              1               Finland  7.632           1.305           1.592
# 1              2                Norway  7.594           1.456           1.582
# 2              3               Denmark  7.555           1.351           1.590
# 3              4               Iceland  7.495           1.343           1.644
# 4              5           Switzerland  7.487           1.420           1.549
# 5              6           Netherlands  7.441           1.361           1.488
# 6              7                Canada  7.328           1.330           1.532
# 7              8           New Zealand  7.324           1.268           1.601
# 8              9                Sweden  7.314           1.355           1.501
# 9             10             Australia  7.272           1.340           1.573
# 10            11        United Kingdom  7.190           1.244           1.433
# ...

# %% [markdown]
# **But after not finding anything clear and not knowing the method of calculate it, I decided to take the mean for the entire column:**

# %%
df_2018['Perceptions of corruption'] = df_2018['Perceptions of corruption'].fillna(df_2018['Perceptions of corruption'].mean())

# %%
df_2018[0:20]
# Out:
#     Overall rank     Country or region  Score  GDP per capita  Social support  \
# 0              1               Finland  7.632           1.305           1.592
# 1              2                Norway  7.594           1.456           1.582
# 2              3               Denmark  7.555           1.351           1.590
# 3              4               Iceland  7.495           1.343           1.644
# 4              5           Switzerland  7.487           1.420           1.549
# 5              6           Netherlands  7.441           1.361           1.488
# 6              7                Canada  7.328           1.330           1.532
# 7              8           New Zealand  7.324           1.268           1.601
# 8              9                Sweden  7.314           1.355           1.501
# 9             10             Australia  7.272           1.340           1.573
# 10            11        United Kingdom  7.190           1.244           1.433
# ...

# %%
df_2018.isna().sum()
# Out:
# Overall rank                    0
# Country or region               0
# Score                           0
# GDP per capita                  0
# Social support                  0
# Healthy life expectancy         0
# Freedom to make life choices    0
# Generosity                      0
# Perceptions of corruption       0
# dtype: int64

# %%
df_2019.isna().sum()
# Out:
# Overall rank                    0
# Country or region               0
# Score                           0
# GDP per capita                  0
# Social support                  0
# Healthy life expectancy         0
# Freedom to make life choices    0
# Generosity                      0
# Perceptions of corruption       0
# dtype: int64

# %%
# go to clean them

# %% [markdown]
# #### 7. Check Accuracy:
#
# Verify that the data is correct and precise. This could involve comparing data samples with known sources or using validation rules.
#
# **The process includes:**
# 1. Validating the appropriateness of data types for the dataset.
# 2. Identifying outliers  using established validation  rule

# %% [markdown]
# **Here we see that all types of data are suitable for the column content and do not require any changes:**

# %%
# check columns types 
df_2015.dtypes
# Out:
# Country                           object
# Happiness Rank                     int64
# Happiness Score                  float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %%
df_2016.dtypes
# Out:
# Country                           object
# Happiness Rank                     int64
# Happiness Score                  float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %%
df_2017.dtypes
# Out:
# Country                           object
# Happiness Rank                     int64
# Happiness Score                  float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Generosity                       float64
# Trust (Government Corruption)    float64
# Dystopia Residual                float64
# dtype: object

# %%
df_2018.dtypes
# Out:
# Overall rank                      int64
# Country or region                object
# Score                           float64
# GDP per capita                  float64
# Social support                  float64
# Healthy life expectancy         float64
# Freedom to make life choices    float64
# Generosity                      float64
# Perceptions of corruption       float64
# dtype: object

# %%
df_2019.dtypes
# Out:
# Overall rank                      int64
# Country or region                object
# Score                           float64
# GDP per capita                  float64
# Social support                  float64
# Healthy life expectancy         float64
# Freedom to make life choices    float64
# Generosity                      float64
# Perceptions of corruption       float64
# dtype: object

# %%
df_2015.columns
# Out:
# Index(['Country', 'Happiness Rank', 'Happiness Score',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Trust (Government Corruption)', 'Generosity',
#        'Dystopia Residual'],
#       dtype='object')

# %%
#as we see here,there is no outliers in df_2015
def detect_outliers_iqr(df_2015, column):
    Q1 = df_2015[column].quantile(0.25)
    Q3 = df_2015[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = df_2015[(df_2015[column] < lower_bound) | (df_2015[column] > upper_bound)]
    return outliers

# %%
iqr_outliers = detect_outliers_iqr(df_2015, 'Happiness Score')
print('IQR Outliers:\n', iqr_outliers)
# Out:
# IQR Outliers:
#  Empty DataFrame
# Columns: [Country, Happiness Rank, Happiness Score, Economy (GDP per Capita), Family, Health (Life Expectancy), Freedom, Generosity, Trust (Government Corruption), Dystopia Residual]
# Index: []

# %%
plt.figure(figsize=(10, 6))
plt.boxplot(df_2015['Happiness Score'], vert=False, patch_artist=True)
plt.title('Box Plot of Happiness Score with IQR Outliers')
plt.xlabel('Happiness Score')
plt.show()

# %%
#as we see here,there is no outliers in df_2016
def detect_outliers_iqr(df_2016, column):
    Q1 = df_2016[column].quantile(0.25)
    Q3 = df_2016[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = df_2016[(df_2016[column] < lower_bound) | (df_2016[column] > upper_bound)]
    return outliers

# %%
iqr_outliers = detect_outliers_iqr(df_2016, 'Happiness Score')
print('IQR Outliers:\n', iqr_outliers)
# Out:
# IQR Outliers:
#  Empty DataFrame
# Columns: [Country, Happiness Rank, Happiness Score, Economy (GDP per Capita), Family, Health (Life Expectancy), Freedom, Trust (Government Corruption), Generosity, Dystopia Residual]
# Index: []

# %%
plt.figure(figsize=(10, 6))
plt.boxplot(df_2016['Happiness Score'], vert=False, patch_artist=True)
plt.title('Box Plot of Happiness Score with IQR Outliers')
plt.xlabel('Happiness Score')
plt.show()

# %%
#as we see here,there is no outliers in df_2017
def detect_outliers_iqr(df_2016, column):
    Q1 = df_2017[column].quantile(0.25)
    Q3 = df_2017[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = df_2017[(df_2017[column] < lower_bound) | (df_2017[column] > upper_bound)]
    return outliers

# %%
iqr_outliers = detect_outliers_iqr(df_2017, 'Happiness Score')
print('IQR Outliers:\n', iqr_outliers)
# Out:
# IQR Outliers:
#  Empty DataFrame
# Columns: [Country, Happiness Rank, Happiness Score, Economy (GDP per Capita), Family, Health (Life Expectancy), Freedom, Generosity, Trust (Government Corruption), Dystopia Residual]
# Index: []

# %%
plt.figure(figsize=(10, 6))
plt.boxplot(df_2017['Happiness Score'], vert=False, patch_artist=True)
plt.title('Box Plot of Happiness Score with IQR Outliers')
plt.xlabel('Happiness Score')
plt.show()

# %% [markdown]
# ## 2. Data Cleaning:
#
# Preliminary findings from data profiling can lead to cleaning the data by:
# - Handling missing values
# - Correcting errors.
# - Dealing with outliers.
#
# -------------------

# %% [markdown]
# ### Handling missing values:

# %%
# i handel it above in 'completeness' section

# %%
# go back to 6th dimention --> Completeness

# %% [markdown]
# ### Correcting errors
#
# -------------------

# %%
consistent_columns_2018 = {
    'Country or region': 'Country',
    'Overall rank': 'Happiness Rank',
    'Score': 'Happiness Score',
    'GDP per capita': 'Economy (GDP per Capita)',
    'Social support': 'Family',
    'Healthy life expectancy': 'Health (Life Expectancy)',
    'Freedom to make life choices': 'Freedom',
    'Perceptions of corruption': 'Trust (Government Corruption)',
    'Generosity': 'Generosity',
    'Year': 'Year',
}

df_2018.rename(columns=consistent_columns_2018, inplace=True)

# %%
df_2018
# Out:
#      Happiness Rank                   Country  Happiness Score  \
# 0                 1                   Finland            7.632
# 1                 2                    Norway            7.594
# 2                 3                   Denmark            7.555
# 3                 4                   Iceland            7.495
# 4                 5               Switzerland            7.487
# ..              ...                       ...              ...
# 151             152                     Yemen            3.355
# 152             153                  Tanzania            3.303
# 153             154               South Sudan            3.254
# 154             155  Central African Republic            3.083
# 155             156                   Burundi            2.905
#
#      Economy (GDP per Capita)  Family  Health (Life Expectancy)  Freedom  \
# 0                       1.305   1.592                     0.874    0.681
# ...

# %%
consistent_columns_2019 = {
    'Country or region': 'Country',
    'Overall rank': 'Happiness Rank',
    'Score': 'Happiness Score',
    'GDP per capita': 'Economy (GDP per Capita)',
    'Social support': 'Family',
    'Healthy life expectancy': 'Health (Life Expectancy)',
    'Freedom to make life choices': 'Freedom',
    'Perceptions of corruption': 'Trust (Government Corruption)',
    'Generosity': 'Generosity',
    'Year': 'Year',
}

df_2019.rename(columns=consistent_columns_2019, inplace=True)

# %%
df_2019
# Out:
#      Happiness Rank                   Country  Happiness Score  \
# 0                 1                   Finland            7.769
# 1                 2                   Denmark            7.600
# 2                 3                    Norway            7.554
# 3                 4                   Iceland            7.494
# 4                 5               Netherlands            7.488
# ..              ...                       ...              ...
# 151             152                    Rwanda            3.334
# 152             153                  Tanzania            3.231
# 153             154               Afghanistan            3.203
# 154             155  Central African Republic            3.083
# 155             156               South Sudan            2.853
#
#      Economy (GDP per Capita)  Family  Health (Life Expectancy)  Freedom  \
# 0                       1.340   1.587                     0.986    0.596
# ...

# %% [markdown]
# ### 1-What countries or regions rank the highest in overall happiness and each of the six factors contributing to happiness?

# %% [markdown]
# #### 2015:

# %%
df_2015.columns
# Out:
# Index(['Country', 'Happiness Rank', 'Happiness Score',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Trust (Government Corruption)', 'Generosity',
#        'Dystopia Residual'],
#       dtype='object')

# %%
df_2016.columns
# Out:
# Index(['Country', 'Happiness Rank', 'Happiness Score',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Trust (Government Corruption)', 'Generosity',
#        'Dystopia Residual'],
#       dtype='object')

# %%
df_2017.columns
# Out:
# Index(['Country', 'Happiness Rank', 'Happiness Score',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Generosity', 'Trust (Government Corruption)',
#        'Dystopia Residual'],
#       dtype='object')

# %%
df_2018.columns
# Out:
# Index(['Happiness Rank', 'Country', 'Happiness Score',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Generosity', 'Trust (Government Corruption)'],
#       dtype='object')

# %%
df_2019.columns
# Out:
# Index(['Happiness Rank', 'Country', 'Happiness Score',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Generosity', 'Trust (Government Corruption)'],
#       dtype='object')

# %%
rank_2015 = df_2015['Happiness Rank'].values[1]
rank_2016 = df_2016['Happiness Rank'].values[1]
rank_2017 = df_2017['Happiness Rank'].values[1]
rank_2018 = df_2018['Happiness Rank'].values[0]
rank_2019 = df_2019['Happiness Rank'].values[0]

data = {
    'Year': [2015, 2016, 2017, 2018, 2019],
    'Happiness Rank': [rank_2015, rank_2016, rank_2017, rank_2018, rank_2019]
}

df_combined = pd.DataFrame(data)

df_combined.set_index('Year', inplace=True)

df_combined.plot(kind='bar', legend=False)
plt.xlabel('Year')
plt.ylabel('Happiness Rank')
plt.title('Happiness Rank by Year')

# Show the plot
plt.show()

# %%
numeric_columns = [
    'Happiness Rank', 'Happiness Score', 'Economy (GDP per Capita)', 
    'Family', 'Health (Life Expectancy)', 'Freedom', 
    'Trust (Government Corruption)', 'Generosity', 
    'Dystopia Residual'
]

# Calculate correlation matrix
correlation_matrix = df_2015[numeric_columns].corr()

# Create the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1, center=0)
plt.title('Correlation Matrix Heatmap for 2015 Data')
plt.show()

# %% [markdown]
# #### 2016:

# %%
numeric_columns = [
    'Happiness Rank', 'Happiness Score', 'Economy (GDP per Capita)', 
    'Family', 'Health (Life Expectancy)', 'Freedom', 
    'Trust (Government Corruption)', 'Generosity', 
    'Dystopia Residual'
]

# Calculate correlation matrix
correlation_matrix = df_2016[numeric_columns].corr()

# Create the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1, center=0)
plt.title('Correlation Matrix Heatmap for 2016 Data')
plt.show()

# %% [markdown]
# #### 2017:

# %%
numeric_columns = [
    'Happiness Rank', 'Happiness Score', 'Economy (GDP per Capita)', 
    'Family', 'Health (Life Expectancy)', 'Freedom', 
    'Trust (Government Corruption)', 'Generosity', 
    'Dystopia Residual'
]

# Calculate correlation matrix
correlation_matrix = df_2017[numeric_columns].corr()

# Create the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1, center=0)
plt.title('Correlation Matrix Heatmap for 2017 Data')
plt.show()

# %% [markdown]
# ### 2-How did country ranks or scores change between the 2015 and 2016 as well as the 2016 and 2017 reports?

# %%
df_2015_top10 = df_2015.head(10)
df_2016_top10 = df_2016.head(10)

plt.scatter(df_2015_top10['Country'], df_2015_top10['Happiness Rank'], label='df_2015')
plt.scatter(df_2016_top10['Country'], df_2016_top10['Happiness Rank'], label='df_2016')

plt.xticks(rotation=45)
plt.xlabel('Country')
plt.ylabel('Happiness Rank')
plt.title('Happiness Rank by Country')
plt.legend()

plt.show()

# %%
df_2016_top10 = df_2016.head(10)
df_2017_top10 = df_2017.head(10)

plt.scatter(df_2016_top10['Country'], df_2016_top10['Happiness Rank'], label='df_2016')
plt.scatter(df_2017_top10['Country'], df_2017_top10['Happiness Rank'], label='df_2017')

plt.xticks(rotation=45)
plt.xlabel('Country')
plt.ylabel('Happiness Rank')
plt.title('Happiness Rank by Country')
plt.legend()

plt.show()

# %% [markdown]
# ### 3-Did any country experience a significant increase or decrease in happiness?

# %%
"""
2015 - 2016
Based on the previous question, we note that in 2015 and 2016, the country that occupied first place in 2015 was Switzerland, 
but it fell to second place in 2016, and what was in second place fell to third.
------------------------------------------
2016 - 2017
One of the noteworthy changes is that Norway was ranked fourth in 2016 and moved up to first place in 2017.
"""

# %% [markdown]
# ### Dealing with outliers:

# %% [markdown]
# **How to remove Outliers?**
# Most of the ways to deal with outliers are similar to the methods of missing values like deleting rows, transforming them, binning them, treat them as a separate group, imputing values and other statistical methods. Here, we will discuss the common techniques used to deal with outliers:
#
# 1. Deleting rows: We delete outlier values if it is due to data entry error, data processing error or outlier rows are very small in numbers. We can also use trimming at both ends to remove outliers.
#
# 2. Imputing: Like imputation of missing values, we can also impute outliers. We can use mean, median, mode imputation methods. Before imputing values, we should analyse if it is natural outlier or artificial. If it is artificial, we can go with imputing values. We can also use statistical model to predict values of outlier rows and after that we can impute it with predicted values.
#
# 3. Treat separately: If there are significant number of outliers, we should treat them separately in the statistical model. One of the approach is to treat both groups as two different groups and build individual model for both groups and then combine the output.

# %%
#there is no outliers

# %% [markdown]
# ### Univariate Graphical Analysis:
# #### i used the following:
# - boxplot : I found out about outliers using code and visualization.

# %% [markdown]
# ### Bivariate/Multivariate Analysis:
# #### I used the following:
# - Bar chart
# - Heatmap
# - Scatter
